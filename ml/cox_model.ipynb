# %%
from lifelines import CoxPHFitter
from lifelines.utils import k_fold_cross_validation
import numpy as np
import pandas as pd
from matplotlib import rcParams
import matplotlib.pyplot as plt
import pickle

# Source - https://stackoverflow.com/a/3900167
rcParams.update({'font.size': 14})

# %% [markdown]
# ---
#
# # Reading the Dataset

# %%
df = pd.read_csv('data/myeloma_data.csv', index_col='ID')
df.head(10)
# Out:
#             Ancestry  PGS_Score        Age   M_Spike  sFLC_Ratio  Creatinine  \
# ID
# 1           European  -0.006056  69.111929  3.282018    3.010026    0.522791
# 2           European   0.996723  74.327334  3.468359    3.372553    1.028067
# 3           European   0.723133  67.378696  0.588324    2.718493    0.775595
# 4           European   0.821519  72.769428  1.222824    6.164781    0.943936
# 5           European  -0.806482  64.201009  2.228350    0.438690    0.978404
# 6           European  -0.781068  70.892523  0.783407    0.333248    0.989162
# 7   African American   0.873980  68.354002  0.820777   13.354222    0.824384
# 8           European  -0.898449  61.421899  1.264078   28.554619    0.908192
# 9           European   1.585733  65.122680  1.084860    1.118959    0.925235
# 10          European  -0.771742  83.049374  0.266902    5.407887    0.662776
#
#           LP  Time_Months  Status  BMPC_Final  Hgb_Final     PGS_Bin  \
# ID
# 1   2.172474        16.02       1   25.010010  14.598307  Medium PGS
# 2   2.034360         0.80       1         NaN  15.478983  Medium PGS
# 3   0.134618       107.38       0    0.150430  12.717573  Medium PGS
# 4   2.541208        51.56       1         NaN        NaN  Medium PGS
# 5   0.603776        45.18       0         NaN  12.620185  Medium PGS
# 6  -0.449451       110.07       0    6.615842  11.630301  Medium PGS
# 7   0.950020        65.93       1         NaN  13.896251  Medium PGS
# 8   1.861289        85.94       0         NaN  11.944470  Medium PGS
# 9   0.790403        13.19       0   16.350008  14.234055    High PGS
# 10 -0.211712       120.00       0         NaN  14.428675  Medium PGS
#
#         Clinical_Risk
# ID
# 1   Int Clinical Risk
# 2   Int Clinical Risk
# 3   Low Clinical Risk
# 4   Low Clinical Risk
# 5   Int Clinical Risk
# 6   Low Clinical Risk
# 7   Low Clinical Risk
# 8   Int Clinical Risk
# 9   Low Clinical Risk
# 10  Low Clinical Risk

# %% [markdown]
# ## Encoding Ancestry

# %%
print(list(df['Ancestry'].unique())) # ['European', 'African American']

# since there are only 2 ancestry values, we can encode as boolean
df['Ancestry'] = df['Ancestry'].map({
    'European': 1,
    'African American': 0
})
df.head(10)
# Out:
# ['European', 'African American']
#     Ancestry  PGS_Score        Age   M_Spike  sFLC_Ratio  Creatinine  \
# ID
# 1          1  -0.006056  69.111929  3.282018    3.010026    0.522791
# 2          1   0.996723  74.327334  3.468359    3.372553    1.028067
# 3          1   0.723133  67.378696  0.588324    2.718493    0.775595
# 4          1   0.821519  72.769428  1.222824    6.164781    0.943936
# 5          1  -0.806482  64.201009  2.228350    0.438690    0.978404
# 6          1  -0.781068  70.892523  0.783407    0.333248    0.989162
# 7          0   0.873980  68.354002  0.820777   13.354222    0.824384
# 8          1  -0.898449  61.421899  1.264078   28.554619    0.908192
# 9          1   1.585733  65.122680  1.084860    1.118959    0.925235
# 10         1  -0.771742  83.049374  0.266902    5.407887    0.662776
#
#           LP  Time_Months  Status  BMPC_Final  Hgb_Final     PGS_Bin  \
# ID
# 1   2.172474        16.02       1   25.010010  14.598307  Medium PGS
# 2   2.034360         0.80       1         NaN  15.478983  Medium PGS
# 3   0.134618       107.38       0    0.150430  12.717573  Medium PGS
# 4   2.541208        51.56       1         NaN        NaN  Medium PGS
# 5   0.603776        45.18       0         NaN  12.620185  Medium PGS
# 6  -0.449451       110.07       0    6.615842  11.630301  Medium PGS
# 7   0.950020        65.93       1         NaN  13.896251  Medium PGS
# 8   1.861289        85.94       0         NaN  11.944470  Medium PGS
# 9   0.790403        13.19       0   16.350008  14.234055    High PGS
# 10 -0.211712       120.00       0         NaN  14.428675  Medium PGS
#
#         Clinical_Risk
# ID
# 1   Int Clinical Risk
# 2   Int Clinical Risk
# 3   Low Clinical Risk
# 4   Low Clinical Risk
# 5   Int Clinical Risk
# 6   Low Clinical Risk
# 7   Low Clinical Risk
# 8   Int Clinical Risk
# 9   Low Clinical Risk
# 10  Low Clinical Risk

# %% [markdown]
# ## Input Ranges
#
# The frontend should only allow predictions for input values within these ranges.

# %%
# Source - https://stackoverflow.com/a/58065394
def my_ceil(a, precision=0):
    return np.true_divide(np.ceil(a * 10**precision), 10**precision)

def my_floor(a, precision=0):
    return np.true_divide(np.floor(a * 10**precision), 10**precision)

for col in ['Age', 'M_Spike', 'sFLC_Ratio', 'Creatinine']:
    min_allowed = my_ceil(df[col].min(), 1)
    max_allowed = my_floor(df[col].max(), 1)
    print(f'{(col+":").ljust(16)}{min_allowed} to {max_allowed}')
# Out:
# Age:            40.0 to 106.1
# M_Spike:        0.1 to 6.3
# sFLC_Ratio:     0.1 to 165.6
# Creatinine:     0.4 to 1.9

# %% [markdown]
# ## Time To Event

# %%
# We use years since it's consistent with PANGEA charts
df['Time_Years'] = df['Time_Months'] / 12

# %% [markdown]
# ---
#
# # Hyperparameter Tuning
#
# The only available hyperparameter in a standard cox model is _alpha_, which regulates how strongly we penalize large coefficients

# %%
def scale_standard(df):
    return (df - df.mean(axis=0)) / df.std(axis=0, ddof=0)

# technically we're not allowed to do this with samples that are then used to evaluate the model
# but I'm sure it's ok
def alpha_search(df):
    best_score = .5
    best_alpha = 0
    alpha_grid = [0.0001, 0.001, 0.01, 0.05, 0.1, 0.2, 0.5, 0.8, 1.0]
    for alpha in alpha_grid:
        cph = CoxPHFitter(alpha=alpha)
        fold_c_scores = k_fold_cross_validation(cph, df, duration_col, event_col, k=5, scoring_method='concordance_index')
        mean_score = np.mean(fold_c_scores)
        print(f'alpha {alpha}: {mean_score}')
        if mean_score >= best_score:
            best_score = mean_score
            best_alpha = alpha
    return best_alpha

standard_lab_cols = [
    'Ancestry', 
    'Age', 
    'M_Spike', 
    'sFLC_Ratio', 
    'Creatinine', 
]
duration_col = 'Time_Years'
event_col = 'Status'
output_df = df[[duration_col, event_col]]
dfx = scale_standard(df[standard_lab_cols]).join(output_df)
optimal = alpha_search(dfx)
print(f'optimal alpha: {optimal}')
# Out:
# alpha 0.0001: 0.6856665107068994
# alpha 0.001: 0.6904772072098583
# alpha 0.01: 0.6882706769471754
# alpha 0.05: 0.6887728131468697
# alpha 0.1: 0.6857729598135239
# alpha 0.2: 0.6877457850319615
# alpha 0.5: 0.6885170675929827
# alpha 0.8: 0.6847491444753131
# alpha 1.0: 0.6842540323341589
# optimal alpha: 0.001

# %% [markdown]
# We can see that alpha doesn't make a significant difference.
# According to the [docs](https://lifelines.readthedocs.io/en/latest/fitters/regression/CoxPHFitter.html#lifelines.fitters.coxph_fitter.CoxPHFitter), lifelines actually already uses `0.05` as the default alpha value, so we'll just leave it like that.

# %% [markdown]
# ---
#
# # Feature Evaluation

# %%
feature_cols = [
    'Ancestry', 
    'Age', 
    'M_Spike', 
    'sFLC_Ratio', 
    'Creatinine', 
    'PGS_Score'
]
duration_col = 'Time_Years'
event_col = 'Status'
cols = feature_cols + [duration_col, event_col]

cph = CoxPHFitter()
cph.fit(df[cols], event_col=event_col, duration_col=duration_col)
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 2000 total observations, 1481 right-censored observations>
#              duration col = 'Time_Years'
#                 event col = 'Status'
#       baseline estimation = breslow
#    number of observations = 2000
# number of events observed = 519
#    partial log-likelihood = -3561.15
#          time fit was run = 2026-03-02 15:07:14 UTC
#
# ---
#             coef exp(coef)  se(coef)  coef lower 95%  coef upper 95% exp(coef) lower 95% exp(coef) upper 95%
# covariate
# Ancestry   -0.02      0.98      0.11           -0.24            0.20                0.79                1.22
# Age         0.02      1.02      0.00            0.01            0.02                1.01                1.02
# M_Spike     0.69      2.00      0.04            0.61            0.78                1.84                2.18
# sFLC_Ratio  0.02      1.02      0.00            0.01            0.02                1.01                1.02
# Creatinine  0.51      1.66      0.18            0.16            0.86                1.17                2.36
# PGS_Score   0.36      1.43      0.04            0.27            0.44                1.31                1.55
#
#             cmp to     z      p  -log2(p)
# covariate
# Ancestry      0.00 -0.18   0.86      0.22
# Age           0.00  3.61 <0.005     11.69
# M_Spike       0.00 15.97 <0.005    188.23
# sFLC_Ratio    0.00  6.86 <0.005     37.11
# Creatinine    0.00  2.85 <0.005      7.84
# PGS_Score     0.00  8.39 <0.005     54.18
# ---
# Concordance = 0.71
# Partial AIC = 7134.29
# log-likelihood ratio test = 304.55 on 6 df
# -log2(p) of ll-ratio test = 206.17

# %%
standard_lab_cols = [
    'Ancestry', 
    'Age', 
    'M_Spike', 
    'sFLC_Ratio', 
    'Creatinine', 
]
duration_col = 'Time_Years'
event_col = 'Status'

def evaluate_model(df):
    
    # 26% is way too high
    # Kyle et al. 2018 -> should be ~10%
    # THIS is the reason why progression predictions are unreasonably high
    print(f"{len(df.index)} probands of which {100*df[event_col].sum() / len(df.index):.0f}% MM progression")

    cph = CoxPHFitter()
    k = 5
    fold_c_scores = k_fold_cross_validation(cph, df, duration_col, event_col, k=k, scoring_method='concordance_index')
    mean_c = np.mean(fold_c_scores)
    print(f"{k}-fold-validation calculated mean c index of {mean_c:.4f}")
    return mean_c

print('LAB VALS')
dfx = df[standard_lab_cols+[duration_col, event_col]]
LAB = evaluate_model(dfx)
print()

print('LAB VALS + PGS SCORE')
dfx = df[standard_lab_cols+['PGS_Score', duration_col, event_col]]
LAB_PGS = evaluate_model(dfx)
print()

print('LAB VALS + BONE MARROW / HEMOGLOBIN')
dfx = df[standard_lab_cols+['BMPC_Final', 'Hgb_Final', duration_col, event_col]]
dfx = dfx[dfx[['BMPC_Final', 'Hgb_Final']].notnull().all(axis=1)]
LAB_BM = evaluate_model(dfx)
print()

print('LAB VALS + PGS SCORE + BONE MARROW / HEMOGLOBIN')
dfx = df[standard_lab_cols+['BMPC_Final', 'Hgb_Final', 'PGS_Score', duration_col, event_col]]
dfx = dfx[dfx[['BMPC_Final', 'Hgb_Final']].notnull().all(axis=1)]
LAB_PGS_BM = evaluate_model(dfx)
# Out:
# LAB VALS
# 2000 probands of which 26% MM progression
# 5-fold-validation calculated mean c index of 0.6891
#
# LAB VALS + PGS SCORE
# 2000 probands of which 26% MM progression
# 5-fold-validation calculated mean c index of 0.7049
#
# LAB VALS + BONE MARROW / HEMOGLOBIN
# 1173 probands of which 26% MM progression
# 5-fold-validation calculated mean c index of 0.7044
#
# LAB VALS + PGS SCORE + BONE MARROW / HEMOGLOBIN
# 1173 probands of which 26% MM progression
# 5-fold-validation calculated mean c index of 0.7203

# %%
import pandas as pd
import matplotlib.pyplot as plt

PANGEA = 0.879
PANGEA_BM = 0.729

df_no_bm = pd.DataFrame([
    {'name': 'Ours', 'score': LAB_PGS},
    {'name': 'PANGEA', 'score': PANGEA},
])

df_bm = pd.DataFrame([
    {'name': 'Ours', 'score': LAB_PGS},
    {'name': 'PANGEA', 'score': PANGEA},
    {'name': 'Ours (with BM)', 'score': LAB_PGS_BM},
    {'name': 'PANGEA (with BM)', 'score': PANGEA_BM},
])

def plot(df, rotation=0):
    plt.figure(figsize=(6, 4))

    colors = ['darkorange' if 'BM' in name else 'C0' for name in df['name']]
    plt.bar(df['name'], df['score'], color=colors)

    plt.ylim(0.5, 1.0)
    plt.ylabel('c-Index', fontsize=14)
    plt.xticks(fontsize=12, rotation=rotation, ha='right' if rotation else 'center')
    plt.yticks(fontsize=12)

    plt.tight_layout()
    plt.show()

plot(df_no_bm)
plot(df_bm, rotation=20)

# %% [markdown]
# ---
#
# # Example Usage for Production Model
#
# 1. Run `pip install -e .` in the root directory to install the core module.
# 2. Run `train.py` to export the model to `models/cox_bootstrap_bundle.pkl`
# 3. Make a prediction using the following script

# %%
from artifacts import PatientFeatures, CoxBootstrapBundle

BUNDLE_PATH = 'models/cox_bootstrap_bundle.pkl'
ALPHA = 0.05

test_patient = PatientFeatures(
    Ancestry=1, # European
    Age=65,
    M_Spike=3.2,
    sFLC_Ratio=1.5,
    Creatinine=1.2,
)
cox_bootstrap = CoxBootstrapBundle.load(BUNDLE_PATH)
prediction = cox_bootstrap.predict_cumulative_incidence(test_patient, alpha=ALPHA)

plt.figure(figsize=(6, 5))
plt.fill_between(
    prediction.index,
    prediction['ci_lower'],
    prediction['ci_upper'],
    color='lightgrey',
    label=f"{int((1-ALPHA)*100)}% bootstrap CI"
)
plt.plot(
    prediction.index, 
    prediction['risk'], 
    label="Estimated progression risk", 
    color='darkred'
)

plt.xlabel("Years in Future")
plt.ylabel("Probability of Progression")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# # Kaplan Meier Chart

# %%
# https://lifelines.readthedocs.io/en/latest/Survival%20analysis%20with%20lifelines.html

from lifelines import KaplanMeierFitter

kmf = KaplanMeierFitter()
kmf.fit(df[duration_col], event_observed=df[event_col])

from matplotlib import pyplot as plt

(1-kmf.survival_function_).plot()
plt.title('Predicted progression from MGUS to MM in simulated patients');
